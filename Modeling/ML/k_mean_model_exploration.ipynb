# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
calls_k_mean_model=pd.read_csv('/Users/angelaivonnesalgadobeltran/Documents/IronHack/Final project/Modeling/ML/calls_k_mean_model.csv')

# %%
calls_k_mean_model.columns
# Out:
# Index(['Unnamed: 0', 'media_edad', 'edad',
#        'prov_residencia_persona_en_situacion_violencia_encode',
#        'genero_persona_en_situacion_de_violencia_encode',
#        'tipo_de_violencia_fisica_encode',
#        'tipo_de_violencia_psicologica_encode',
#        'tipo_de_violencia_sexual_encode',
#        'tipo_de_violencia_economica_y_patrimonial_encode',
#        'tipo_de_violencia_simbolica_encode',
#        'tipo_de_violencia_domestica_encode',
#        'modalidad_de_violencia_institucional_encode',
#        'modalidad_de_violencia_laboral_encode',
#        'modalidad_violencia_contra_libertad_reproductiva_encode',
#        'modalidad_de_violencia_obstetrica_encode',
#        'modalidad_de_violencia_mediatica_encode',
#        'modalidad_de_violencia_otras_encode',
#        'vinculo_con_la_persona_agresora_encode',
#        'genero_de_la_persona_agresora_encode', 'consolidado_violencias',
#        'labels_kmeans'],
#       dtype='object')

# %%
sns.displot(calls_k_mean_model, x="edad", y='labels_kmeans')
plt.title('Age Repartition Depending of Cluster Number')
# Out:
# Text(0.5, 1.0, 'Age Repartition Depending of Cluster Number')

# %%
sns.set_style("whitegrid")
sns.set_palette("RdBu")
sns.axes_style()

sns.countplot(calls_k_mean_model['labels_kmeans'])
plt.title('Labels Distribution')
# Out:
# /Users/angelaivonnesalgadobeltran/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Labels Distribution')

# %%
import phik
sns.heatmap(calls_k_mean_model.phik_matrix())
# Out:
# interval columns not set, guessing: ['Unnamed: 0', 'media_edad', 'edad', 'prov_residencia_persona_en_situacion_violencia_encode', 'genero_persona_en_situacion_de_violencia_encode', 'tipo_de_violencia_fisica_encode', 'tipo_de_violencia_psicologica_encode', 'tipo_de_violencia_sexual_encode', 'tipo_de_violencia_economica_y_patrimonial_encode', 'tipo_de_violencia_simbolica_encode', 'tipo_de_violencia_domestica_encode', 'modalidad_de_violencia_institucional_encode', 'modalidad_de_violencia_laboral_encode', 'modalidad_violencia_contra_libertad_reproductiva_encode', 'modalidad_de_violencia_obstetrica_encode', 'modalidad_de_violencia_mediatica_encode', 'modalidad_de_violencia_otras_encode', 'vinculo_con_la_persona_agresora_encode', 'genero_de_la_persona_agresora_encode', 'consolidado_violencias', 'labels_kmeans']
# <AxesSubplot:>

# %%
calls_kmean_0 = calls_k_mean_model.loc[calls_k_mean_model['labels_kmeans'] ==0]
calls_kmean_0
sns.set_style("whitegrid")
sns.set_palette("RdBu")
sns.axes_style()
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)

sns.countplot(calls_kmean_0['edad'])
plt.title('Age Distribution in Cluster 0')
# Out:
# /Users/angelaivonnesalgadobeltran/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age Distribution in Cluster 0')

# %%
calls_kmean_1 = calls_k_mean_model.loc[calls_k_mean_model['labels_kmeans'] ==1]
calls_kmean_1
sns.set_style("whitegrid")
sns.set_palette("RdBu")
sns.axes_style()
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)

sns.countplot(calls_kmean_1['edad'])
plt.title('Age Distribution in Cluster 1')
# Out:
# /Users/angelaivonnesalgadobeltran/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age Distribution in Cluster 1')

# %%
calls_kmean_2 = calls_k_mean_model.loc[calls_k_mean_model['labels_kmeans'] ==2]
calls_kmean_2
sns.set_style("whitegrid")
sns.set_palette("RdBu")
sns.axes_style()

plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.countplot(calls_kmean_2['edad'])
plt.title('Age Distribution in Cluster 2')
# Out:
# /Users/angelaivonnesalgadobeltran/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age Distribution in Cluster 2')

# %%
calls_kmean_3 = calls_k_mean_model.loc[calls_k_mean_model['labels_kmeans'] ==3]
calls_kmean_3
sns.set_style("whitegrid")
sns.set_palette("RdBu")
sns.axes_style()
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)

fig=sns.countplot(calls_kmean_3['edad'])
plt.title('Age Distribution in Cluster 3')
# Out:
# /Users/angelaivonnesalgadobeltran/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age Distribution in Cluster 3')
